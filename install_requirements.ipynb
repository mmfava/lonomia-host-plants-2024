# %%
# Instalar pacotes do CRAN
options(repos = c(CRAN = "https://cran.r-project.org"))
install.packages("units")
install.packages("sf")
install.packages("rnaturalearth")
install.packages("terra")
install.packages("CoordinateCleaner")
install.packages("maps") # Mapas
install.packages("tidyverse") # Manipulação e visualização de dados
install.packages("janitor") # Limpar nomes de colunas da tabela
install.packages("leaflet") # Mapas interativos
install.packages("readxl") # Ler arquivos Excel
install.packages("sp") # Classes e métodos para dados espaciais
install.packages("cowplot") # Arranjar gráficos do ggplot2
install.packages("eks")
#install.packages("TNRS")

# %%
# Verificar se os pacotes foram instalados corretamente
pacotes <- c("CoordinateCleaner", "maps", "tidyverse", "janitor", "leaflet", "readxl", "sf", "sp", "cowplot")
pacotes_instalados <- pacotes %in% rownames(installed.packages())
if (all(pacotes_instalados)) {
    message("Todos os pacotes foram instalados com sucesso.")
} else {
    message("Alguns pacotes não foram instalados:", paste(pacotes[!pacotes_instalados], collapse = ", "))
}
# Out:
# Todos os pacotes foram instalados com sucesso.

# %%
# Carregar os pacotes
library("units")
library("sf")
library("rnaturalearth")
library("terra")
library("CoordinateCleaner")
library("maps") # Mapas
library("tidyverse") # Manipulação e visualização de dados
library("janitor") # Limpar nomes de colunas da tabela
library("leaflet") # Mapas interativos
library("readxl") # Ler arquivos Excel
library("sp") # Classes e métodos para dados espaciais
library("cowplot") # Arranjar gráficos do ggplot2
library("eks")
# Out:
# Warning message:
# “multiple udunits databases present:
#  - /opt/conda/share/udunits/udunits2.xml
#  - /usr/share/xml/udunits/udunits2.xml”
# udunits database from /opt/conda/share/udunits/udunits2.xml
#
# Linking to GEOS 3.12.1, GDAL 3.8.3, PROJ 9.3.1; sf_use_s2() is TRUE
#
# terra 1.7.71
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ tidyr::extract() masks terra::extract()
# ✖ dplyr::filter()  masks stats::filter()
# ✖ dplyr::lag()     masks stats::lag()
# ✖ purrr::map()     masks maps::map()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# ...

# %%
s = sessionInfo()

# %%
s
# Out:
# R version 4.3.2 (2023-10-31)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 22.04.3 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.26.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Etc/UTC
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] eks_1.0.4               cowplot_1.1.3           sp_2.1-3
#  [4] readxl_1.4.3            leaflet_2.2.1           janitor_2.2.0
#  [7] lubridate_1.9.3         forcats_1.0.0           stringr_1.5.1
# [10] dplyr_1.1.4             purrr_1.0.2             readr_2.1.4
# ...

# %%
s[1]
# Out:
# $R.version
# $R.version$platform
# [1] "x86_64-conda-linux-gnu"
#
# $R.version$arch
# [1] "x86_64"
#
# $R.version$os
# [1] "linux-gnu"
#
# $R.version$system
# [1] "x86_64, linux-gnu"
#
# $R.version$status
# [1] ""
#
# $R.version$major
# [1] "4"
#
# $R.version$minor
# [1] "3.2"
#
# $R.version$year
# [1] "2023"
#
# $R.version$month
# [1] "10"
#
# $R.version$day
# [1] "31"
#
# $R.version$`svn rev`
# [1] "85441"
#
# $R.version$language
# [1] "R"
#
# $R.version$version.string
# [1] "R version 4.3.2 (2023-10-31)"
#
# $R.version$nickname
# [1] "Eye Holes"

# %%
s[10]
# Out:
# $loadedOnly
# $loadedOnly$tidyselect
# Package: tidyselect
# Title: Select from a Set of Strings
# Version: 1.2.0
# Authors@R: c( person("Lionel", "Henry", , "lionel@rstudio.com", role =
#         c("aut", "cre")), person("Hadley", "Wickham", ,
#         "hadley@rstudio.com", role = "aut"), person("RStudio", role =
#         c("cph", "fnd")) )
# Description: A backend for the selecting functions of the 'tidyverse'.
#         It makes it easy to implement select-like functions in your own
#         packages in a way that is consistent with other 'tidyverse'
#         interfaces for selection.
# License: MIT + file LICENSE
# URL: https://tidyselect.r-lib.org, https://github.com/r-lib/tidyselect
# BugReports: https://github.com/r-lib/tidyselect/issues
# Depends: R (>= 3.4)
# Imports: cli (>= 3.3.0), glue (>= 1.3.0), lifecycle (>= 1.0.3), rlang
#         (>= 1.0.4), vctrs (>= 0.4.1), withr
# Suggests: covr, crayon, dplyr, knitr, magrittr, rmarkdown, stringr,
# ...
