# %%
## Packages --------------------------------------------------------------------
library(tidyverse) # data manipulation and visualization
library(janitor) # clear table column name
library(magrittr) # pip types
library(gtsummary) # result tables
library(gt) # change table format
library(gtExtras)

## Negate funcion ---------------------------------------------------------------
`%!in%` = Negate(`%in%`)

## Session info ------------------------------------------------------------------
sessionInfo()
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test
#
#
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract
#
#
# #Uighur
# R version 4.3.2 (2023-10-31)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 22.04.3 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.26.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Etc/UTC
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] gtExtras_0.5.0  gt_0.10.1       gtsummary_1.7.2 magrittr_2.0.3
#  [5] janitor_2.2.0   lubridate_1.9.3 forcats_1.0.0   stringr_1.5.1
#  [9] dplyr_1.1.4     purrr_1.0.2     readr_2.1.4     tidyr_1.3.0
# [13] tibble_3.2.1    ggplot2_3.4.4   tidyverse_2.0.0
#
# loaded via a namespace (and not attached):
#  [1] utf8_1.2.4           generics_0.1.3       xml2_1.3.6
#  [4] stringi_1.8.3        hms_1.1.3            digest_0.6.33
#  [7] evaluate_0.23        grid_4.3.2           timechange_0.2.0
# [10] pbdZMQ_0.3-10        fastmap_1.1.1        broom.helpers_1.14.0
# [13] jsonlite_1.8.8       rematch2_2.1.2       fansi_1.0.6
# [16] scales_1.3.0         cli_3.6.2            rlang_1.1.2
# [19] crayon_1.5.2         munsell_0.5.0        base64enc_0.1-3
# [22] withr_2.5.2          repr_1.1.6           tools_4.3.2
# [25] tzdb_0.4.0           uuid_1.1-1           colorspace_2.1-0
# [28] paletteer_1.6.0      IRdisplay_1.1        vctrs_0.6.5
# [31] R6_2.5.1             lifecycle_1.0.4      snakecase_0.11.1
# [34] fontawesome_0.5.2    pkgconfig_2.0.3      pillar_1.9.0
# [37] gtable_0.3.4         glue_1.6.2           xfun_0.41
# [40] tidyselect_1.2.0     knitr_1.45           IRkernel_1.3.2
# [43] htmltools_0.5.7      compiler_4.3.2

# %%
## host data -----------------------------------------------------------------
# (we will use the data in another function)
status_hst <- readxl::read_excel(here::here("data", "hosts.xlsx"), 
                sheet = "survey_info_hosts") |>
  clean_names() |>
  select(-latex) |>
  mutate(native = ifelse(native == "yes", 1, 0)) |>
  mutate(one_antro_use = +any(str_detect(c_across(use_popular_medicine:use_agroforestry), "yes"))) |>
  mutate(sps_name = paste0(host_complete_name, " ", canonical_author))

names(status_hst)
# Out:
#  [1] "host_complete_name"          "genus"
#  [3] "specific_epithet"            "canonical_author"
#  [5] "family"                      "lonomia_species"
#  [7] "status"                      "native"
#  [9] "endemic_south_america"       "endemic_biome_south_america"
# [11] "use_popular_medicine"        "use_consume_fruits"
# [13] "fruit_popular_name"          "use_fruits_commercialized"
# [15] "use_energy_generation"       "use_of_wood"
# [17] "use_for_paper"               "use_urban_afforestation"
# [19] "use_agroforestry"            "red_list_status"
# [21] "deciduos"                    "semideciduos"
# [23] "evergreen"                   "light_demand"
# [25] "one_antro_use"               "sps_name"

# %% [markdown]
# ## Functions

# %%
# Define the function named `add_stat_pairwise_cs`
add_stat_pairwise_cs <- function(data, variable, by, tbl,...) {
  # Extract the column specified by 'variable' from the dataframe 'data'
  d = data[[variable]]
  
  # Perform a chi-squared test on the non-null values of the selected data column
  e = chisq.test(table(na.omit(d)))
  
  # Get the length of residuals from the chi-squared test
  l = length(e$residuals)
  
  # Initialize class_ress with default value "-"
  class_ress <- c("-")
  
  # Check if the length of residuals is not equal to 1
  if(l != 1){
    # Define a helper function `fq_class` to assign symbols based on conditions
    fq_class <- function(res, p_value) {
      # If p-value < 0.05 and residual is negative, return "▼"
      # If p-value < 0.05 and residual is positive, return "▲"
      # Else, return "-"
      case_when(
        p_value < 0.05 & res < -1.96 ~ "▼",
        p_value < 0.05 & res > 1.96 ~ "▲",
        TRUE ~ "-"
      )
    }
    
    # Call `fq_class` with residuals and p-value of the chi-squared test result
    class_res <- fq_class(e$residuals, e$p.value)
  }
  
  # Return a tibble with the calculated residuals as its content
  return(tibble(residuals = class_res))
}

## -----------------------------------

# Define a function named `add_stat_pairwise_csp` with parameters data, variable, by, tbl and other potential arguments (...)
add_stat_pairwise_csp <- function(data, variable, by, tbl, ...) {
  # Extract the column specified by 'variable' from the dataframe 'data'
  d <- data[[variable]]

  # The pipe operator ('|>') sequentially passes the result of one operation to the next.
  e <- d[!is.na(d)] |>
    table() |>
    chisq.test()

  # Create a new tibble (a type of DataFrame in R), with a single row and column.
  # The column name is "p", and the value in this column is the p-value from the chi-squared test.
  tibble("p" = e$p.value)
}

## -----------------------------------

# Define how types will be represented in the output summary,
# here we're considering all categorical variables as 'categorical'
type <- list(all_categorical() ~ "categorical")

#  Define labels for variables
label <- list(
  use_popular_medicine ~ "Popular medicine",
  use_consume_fruits ~ "Edible fruits",
  use_fruits_commercialized ~ "Marketable fruits",
  use_energy_generation ~ "Power generation (coal or firewood)",
  use_of_wood ~ "Commercial wood",
  use_for_paper ~ "Paper",
  use_urban_afforestation ~ "Urban afforestation",
  use_agroforestry ~ "Agroforestry"
)

# This function generates a summarized data table for given status history and species
antrop_desc <- function(status_hst, sp) {
  # Filter rows with matching species and select relevant columns
  status_hst |>
    filter(str_detect(lonomia_species, sp)) |>
    select(use_popular_medicine:use_energy_generation, use_of_wood:use_agroforestry) |>
    # Create a summary table with customized type and label settings
    tbl_summary(
      missing = "no",
      type = type,
      label = label
    ) |>
    # Add additional pairwise crosstab statistics to the summary
    add_stat(
      fns = all_categorical() ~ add_stat_pairwise_cs,
      location = everything() ~ "level"
    ) |>
    # Add a second set of pairwise crosstab statistics to the summary
    add_stat(fns = all_categorical() ~ add_stat_pairwise_csp) |>
    # Modify the headers in the report
    modify_header(
      p = "**p-value**", # The header for the p-value column
      label = "**variables**", # The header for the variables column
      residuals = "**freq. class.**" # Header for frequency class column
    ) |>
    # Modify the footnotes in the report
    modify_footnote(
      p ~ "Chi-Square Goodness of Fit Test (α = 0.05)", # Footnote for the Chi-square test
      residuals ~ "Frequency classification" # Footnote for frequency classification
    ) |>
    # Modify how p-values are presented in the table, limit to 3 decimal points
    modify_fmt_fun(
      update = p ~ function(x) style_pvalue(x, digits = 3)
    )
}

## -----------------------------------

# Define a function to create a summary table describing distributions for given status history and species
distrib_desc <- function(status_hst, sp){
  # Filter data by matching species and native state, then select relevant columns
  status_hst |>
    filter(str_detect(lonomia_species, sp) & native == 1) |>
    select(
      endemic_south_america, # native
      endemic_biome_south_america,
      red_list_status,
      deciduos:evergreen,
      light_demand
    ) |>
        # Create summary table with specified type-label pairs and calculated statistics
    tbl_summary(
      missing = "no",
      type = list(all_categorical() ~ "categorical"),
      label = list(
        red_list_status ~ "Red list status",
        endemic_south_america ~ "Endemic in South America",
        endemic_biome_south_america ~ "Endemic in a biome",
        deciduos ~ "Deciduos",
        semideciduos ~ "Semideciduos",
        evergreen ~ "Evergreen",
        light_demand ~ "Light demander/Heliophile")) |>   

    # Add additional stats to the summary  
    add_stat(fns = all_categorical() ~ add_stat_pairwise_cs, 
             location = all_categorical() ~ "level") |> 

    # Add a second set of pairwise crosstab statistics to the summary   
    add_stat(fns = all_categorical() ~ add_stat_pairwise_csp) |>  

    # Modify table headers and footnotes, formatting p-value to 3 decimal points
    modify_header(p = "**p-value**", 
                  label = "**variables**",
                  residuals = "**freq. class.**") |>
    modify_footnote(p ~ "Chi-Square Goodness of Fit Test (α = 0.05)",
                    residuals ~ "Frequency classification") |> 
    modify_fmt_fun(update = p ~ function(x) style_pvalue(x, digits = 3))
}


## -----------------------------------

# Define a function to create a summary table describing families for given status history and species
family_desc <- function(status_hst, sp) {
  # Define an inner function to add genus to the data frame.
  add_genus <- function(data, variable, ...) {
    # Create new dataframe with family, genus and species, filter by specified species
    data.frame(
      family = status_hst[["family"]],
      genus = status_hst[["host_complete_name"]],
      sps = status_hst[["lonomia_species"]]
    ) %>%
      filter(str_detect(sps, {{ sp }})) %>%
      dplyr::group_by(family) %>%
      dplyr::summarise(genus = paste(genus, collapse = ", ")) %>%
      select(genus)
  }

  # Filter data by matching species, then select relevant columns
  status_hst |>
    filter(str_detect(lonomia_species, sp)) |>
    select(family, genus) |>
    # Create summary table with specified type-label pairs and calculated statistics
    tbl_summary(
      missing = "no",
      include = -genus,
      type = list(all_categorical() ~ "categorical"),
      label = list(family ~ "Family")
    ) |>
    # Add additional stats and genus (from add_genus function) to the summary
    add_stat(
      fns = all_categorical() ~ add_stat_pairwise_cs,
      location = all_categorical() ~ "level"
    ) |>
    add_stat(fns = all_categorical() ~ add_stat_pairwise_csp) |>
    add_stat(
      fns = all_categorical() ~ add_genus,
      location = all_categorical() ~ "level"
    ) |>
    # Modify table headers
    modify_header(
      p = "**p-value**",
      label = "**variables**",
      residuals = "**freq. class.**",
      genus = "**Host species**"
    )
}

# %% [markdown]
# ## Resultados

# %%
# Create a merged table for two species from the family_desc function output
tbl_merge(
    list(
        # Generate summary data using the family_desc function for the 'achelous' species
        family_desc(status_hst, "achelous"),

        # Generate summary data using the family_desc function for the 'obliqua' species
        family_desc(status_hst, "obliqua")
    ),

    # Define labels for each sub-table in the merged table
    tab_spanner = c("*Lonomia achelous*", "*Lonomia obliqua*")) |>

    # Bold the label text in the table
    bold_labels() |>
    
    # Convert the table to a gt object for additional styling options
    as_gt() |>
    
    # Set the font size for the entire table
    gt::tab_options(table.font.size = "12px")
# Out:
# There was an warning for variable 'family':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'family':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'family':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'family':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
# <div id="cuhotmhdjc" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>#cuhotmhdjc table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #cuhotmhdjc thead, #cuhotmhdjc tbody, #cuhotmhdjc tfoot, #cuhotmhdjc tr, #cuhotmhdjc td, #cuhotmhdjc th {
#   border-style: none;
# }
#
# #cuhotmhdjc p {
#   margin: 0;
#   padding: 0;
# }
#
# #cuhotmhdjc .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 12px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #cuhotmhdjc .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #cuhotmhdjc .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #cuhotmhdjc .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #cuhotmhdjc .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #cuhotmhdjc .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #cuhotmhdjc .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #cuhotmhdjc .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #cuhotmhdjc .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #cuhotmhdjc .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #cuhotmhdjc .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #cuhotmhdjc .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #cuhotmhdjc .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #cuhotmhdjc .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #cuhotmhdjc .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #cuhotmhdjc .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #cuhotmhdjc .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #cuhotmhdjc .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #cuhotmhdjc .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #cuhotmhdjc .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #cuhotmhdjc .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #cuhotmhdjc .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #cuhotmhdjc .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #cuhotmhdjc .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #cuhotmhdjc .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #cuhotmhdjc .gt_left {
#   text-align: left;
# }
#
# #cuhotmhdjc .gt_center {
#   text-align: center;
# }
#
# #cuhotmhdjc .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #cuhotmhdjc .gt_font_normal {
#   font-weight: normal;
# }
#
# #cuhotmhdjc .gt_font_bold {
#   font-weight: bold;
# }
#
# #cuhotmhdjc .gt_font_italic {
#   font-style: italic;
# }
#
# #cuhotmhdjc .gt_super {
#   font-size: 65%;
# }
#
# #cuhotmhdjc .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #cuhotmhdjc .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #cuhotmhdjc .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #cuhotmhdjc .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #cuhotmhdjc .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #cuhotmhdjc .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #cuhotmhdjc .gt_indent_5 {
#   text-indent: 25px;
# }
# </style>
#   <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
#   <thead>
#     <tr class="gt_col_headings gt_spanner_row">
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="2" colspan="1" scope="col" id="&lt;strong&gt;variables&lt;/strong&gt;"><strong>variables</strong></th>
#       <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="4" scope="colgroup" id="&lt;em&gt;Lonomia achelous&lt;/em&gt;">
#         <span class="gt_column_spanner"><em>Lonomia achelous</em></span>
#       </th>
#       <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="4" scope="colgroup" id="&lt;em&gt;Lonomia obliqua&lt;/em&gt;">
#         <span class="gt_column_spanner"><em>Lonomia obliqua</em></span>
#       </th>
#     </tr>
#     <tr class="gt_col_headings">
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;N = 9&lt;/strong&gt;&lt;span class=&quot;gt_footnote_marks&quot; style=&quot;white-space:nowrap;font-style:italic;font-weight:normal;&quot;&gt;&lt;sup&gt;1&lt;/sup&gt;&lt;/span&gt;"><strong>N = 9</strong><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>1</sup></span></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;freq. class.&lt;/strong&gt;"><strong>freq. class.</strong></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;p-value&lt;/strong&gt;"><strong>p-value</strong></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;Host species&lt;/strong&gt;"><strong>Host species</strong></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;N = 55&lt;/strong&gt;&lt;span class=&quot;gt_footnote_marks&quot; style=&quot;white-space:nowrap;font-style:italic;font-weight:normal;&quot;&gt;&lt;sup&gt;1&lt;/sup&gt;&lt;/span&gt;"><strong>N = 55</strong><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>1</sup></span></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;freq. class.&lt;/strong&gt;"><strong>freq. class.</strong></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;p-value&lt;/strong&gt;"><strong>p-value</strong></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;Host species&lt;/strong&gt;"><strong>Host species</strong></th>
#     </tr>
#   </thead>
#   <tbody class="gt_table_body">
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Family</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.981</td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center">0.049</td>
# <td headers="genus_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Anacardiaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center">2 (22%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center">Tapirira guianensis, Schinus terebinthifolia</td>
# <td headers="stat_0_2" class="gt_row gt_center">3 (5.5%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Mangifera indica, Lithraea molleoides, Lithraea brasiliensis</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Annonaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center">1 (11%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center">Annona emarginata</td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Annona emarginata</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Euphorbiaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center">1 (11%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center">Hevea brasiliensis</td>
# <td headers="stat_0_2" class="gt_row gt_center">2 (3.6%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Alchornea glandulosa, Sebastiania brasiliensis</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Fabaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center">2 (22%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center">Erythrina cristagalli, Machaerium paraguariense</td>
# <td headers="stat_0_2" class="gt_row gt_center">6 (11%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▲</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Albizia niopoides, Bauhinia forficata, Erythrina cristagalli, Sesbania virgata, Dahlstedtia muehlbergiana, Muellera campestris</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Lauraceae</td>
# <td headers="stat_0_1" class="gt_row gt_center">1 (11%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center">Ocotea lancifolia</td>
# <td headers="stat_0_2" class="gt_row gt_center">3 (5.5%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Persea americana, Nectandra lanceolata, Nectandra grandiflora</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Meliaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center">1 (11%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center">Cedrela fissilis</td>
# <td headers="stat_0_2" class="gt_row gt_center">2 (3.6%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Melia azedarach, Cedrela fissilis</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Rosaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center">1 (11%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center">Pyrus communis</td>
# <td headers="stat_0_2" class="gt_row gt_center">7 (13%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▲</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Prunus domestica, Mespilus germanica, Pyrus communis, Malus pumila, Prunus persica, Rubus ulmifolius, Eriobotrya japonica</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Apocynaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Aspidosperma camporum</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Aquifoliaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Ilex taubertiana</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Araliaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Didymopanax morototoni</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Bignoniaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">2 (3.6%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Handroanthus umbellatus, Handroanthus pulcherrimus</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Lamiaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Vitex megapotamica</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Lythraceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Lagerstroemia indica</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Malvaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Luehea divaricata</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Moraceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">6 (11%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▲</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Ficus carica, Morus nigra, Ficus elastica, Ficus pertusa, Ficus luschnathiana, Ficus pallida</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Myrtaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Psidium guajava</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Pittosporaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Pittosporum tobira</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Platanaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Platanus acerifolia</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Proteaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Grevillea robusta</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Rhamnaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Hovenia dulcis</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Rutaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">3 (5.5%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Citrus limon, Citrus sinensis, Helietta apiculata</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Salicaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">3 (5.5%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Casearia sylvestris, Banara tomentosa, Casearia decandra</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Sapindaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Matayba elaeagnoides</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Sapotaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Pouteria salicifolia</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Solanaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Solanum pseudoquina</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Styracaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Styrax leprosus</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Urticaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Urera aurantiaca</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    Verbenaceae</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="genus_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.8%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td>
# <td headers="genus_2" class="gt_row gt_center">Duranta erecta</td></tr>
#   </tbody>
#
#   <tfoot class="gt_footnotes">
#     <tr>
#       <td class="gt_footnote" colspan="9"><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>1</sup></span> n (%)</td>
#     </tr>
#   </tfoot>
# </table>
# </div>

# %%
## Tabela antropogenic
tbl_merge(
    list(
        antrop_desc(status_hst, "achelous"),
        antrop_desc(status_hst, "obliqua")
    ),
    tab_spanner = c("*Lonomia achelous*", "*Lonomia obliqua*")
) |>
    bold_labels() |>
    as_gt() |>
    gt::tab_options(table.font.size = "12px")
# Out:
# There was an warning for variable 'use_popular_medicine':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_consume_fruits':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'fruit_popular_name':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_fruits_commercialized':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_energy_generation':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_of_wood':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_for_paper':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_urban_afforestation':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_agroforestry':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_popular_medicine':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_consume_fruits':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'fruit_popular_name':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_fruits_commercialized':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_energy_generation':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_of_wood':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_for_paper':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_urban_afforestation':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'use_agroforestry':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'fruit_popular_name':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
#
# There was an warning for variable 'fruit_popular_name':
# simpleWarning in stats::chisq.test(x, y, ...): Chi-squared approximation may be incorrect
# <div id="tidmtduidd" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>#tidmtduidd table {
#   font-family: system-ui, 'Segoe UI', Roboto, Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol', 'Noto Color Emoji';
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# #tidmtduidd thead, #tidmtduidd tbody, #tidmtduidd tfoot, #tidmtduidd tr, #tidmtduidd td, #tidmtduidd th {
#   border-style: none;
# }
#
# #tidmtduidd p {
#   margin: 0;
#   padding: 0;
# }
#
# #tidmtduidd .gt_table {
#   display: table;
#   border-collapse: collapse;
#   line-height: normal;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 12px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #tidmtduidd .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #tidmtduidd .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 3px;
#   padding-bottom: 5px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #tidmtduidd .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #tidmtduidd .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #tidmtduidd .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #tidmtduidd .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #tidmtduidd .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #tidmtduidd .gt_spanner_row {
#   border-bottom-style: hidden;
# }
#
# #tidmtduidd .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #tidmtduidd .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #tidmtduidd .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #tidmtduidd .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #tidmtduidd .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #tidmtduidd .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #tidmtduidd .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #tidmtduidd .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #tidmtduidd .gt_row_group_first th {
#   border-top-width: 2px;
# }
#
# #tidmtduidd .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #tidmtduidd .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #tidmtduidd .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #tidmtduidd .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_last_grand_summary_row_top {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: double;
#   border-bottom-width: 6px;
#   border-bottom-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #tidmtduidd .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #tidmtduidd .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #tidmtduidd .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #tidmtduidd .gt_left {
#   text-align: left;
# }
#
# #tidmtduidd .gt_center {
#   text-align: center;
# }
#
# #tidmtduidd .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #tidmtduidd .gt_font_normal {
#   font-weight: normal;
# }
#
# #tidmtduidd .gt_font_bold {
#   font-weight: bold;
# }
#
# #tidmtduidd .gt_font_italic {
#   font-style: italic;
# }
#
# #tidmtduidd .gt_super {
#   font-size: 65%;
# }
#
# #tidmtduidd .gt_footnote_marks {
#   font-size: 75%;
#   vertical-align: 0.4em;
#   position: initial;
# }
#
# #tidmtduidd .gt_asterisk {
#   font-size: 100%;
#   vertical-align: 0;
# }
#
# #tidmtduidd .gt_indent_1 {
#   text-indent: 5px;
# }
#
# #tidmtduidd .gt_indent_2 {
#   text-indent: 10px;
# }
#
# #tidmtduidd .gt_indent_3 {
#   text-indent: 15px;
# }
#
# #tidmtduidd .gt_indent_4 {
#   text-indent: 20px;
# }
#
# #tidmtduidd .gt_indent_5 {
#   text-indent: 25px;
# }
# </style>
#   <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
#   <thead>
#     <tr class="gt_col_headings gt_spanner_row">
#       <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="2" colspan="1" scope="col" id="&lt;strong&gt;variables&lt;/strong&gt;"><strong>variables</strong></th>
#       <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="3" scope="colgroup" id="&lt;em&gt;Lonomia achelous&lt;/em&gt;">
#         <span class="gt_column_spanner"><em>Lonomia achelous</em></span>
#       </th>
#       <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="3" scope="colgroup" id="&lt;em&gt;Lonomia obliqua&lt;/em&gt;">
#         <span class="gt_column_spanner"><em>Lonomia obliqua</em></span>
#       </th>
#     </tr>
#     <tr class="gt_col_headings">
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;N = 9&lt;/strong&gt;&lt;span class=&quot;gt_footnote_marks&quot; style=&quot;white-space:nowrap;font-style:italic;font-weight:normal;&quot;&gt;&lt;sup&gt;1&lt;/sup&gt;&lt;/span&gt;"><strong>N = 9</strong><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>1</sup></span></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;freq. class.&lt;/strong&gt;&lt;span class=&quot;gt_footnote_marks&quot; style=&quot;white-space:nowrap;font-style:italic;font-weight:normal;&quot;&gt;&lt;sup&gt;2&lt;/sup&gt;&lt;/span&gt;"><strong>freq. class.</strong><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>2</sup></span></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;p-value&lt;/strong&gt;&lt;span class=&quot;gt_footnote_marks&quot; style=&quot;white-space:nowrap;font-style:italic;font-weight:normal;&quot;&gt;&lt;sup&gt;3&lt;/sup&gt;&lt;/span&gt;"><strong>p-value</strong><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>3</sup></span></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;N = 55&lt;/strong&gt;&lt;span class=&quot;gt_footnote_marks&quot; style=&quot;white-space:nowrap;font-style:italic;font-weight:normal;&quot;&gt;&lt;sup&gt;1&lt;/sup&gt;&lt;/span&gt;"><strong>N = 55</strong><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>1</sup></span></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;freq. class.&lt;/strong&gt;&lt;span class=&quot;gt_footnote_marks&quot; style=&quot;white-space:nowrap;font-style:italic;font-weight:normal;&quot;&gt;&lt;sup&gt;2&lt;/sup&gt;&lt;/span&gt;"><strong>freq. class.</strong><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>2</sup></span></th>
#       <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="&lt;strong&gt;p-value&lt;/strong&gt;&lt;span class=&quot;gt_footnote_marks&quot; style=&quot;white-space:nowrap;font-style:italic;font-weight:normal;&quot;&gt;&lt;sup&gt;3&lt;/sup&gt;&lt;/span&gt;"><strong>p-value</strong><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>3</sup></span></th>
#     </tr>
#   </thead>
#   <tbody class="gt_table_body">
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Popular medicine</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.096</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center"><0.001</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    no</td>
# <td headers="stat_0_1" class="gt_row gt_center">2 (22%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">11 (21%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▼</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    yes</td>
# <td headers="stat_0_1" class="gt_row gt_center">7 (78%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">42 (79%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▲</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Edible fruits</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.317</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center">0.057</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    no</td>
# <td headers="stat_0_1" class="gt_row gt_center">6 (67%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">34 (63%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    yes</td>
# <td headers="stat_0_1" class="gt_row gt_center">3 (33%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">20 (37%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">fruit_popular_name</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.040</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center"><0.001</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    -</td>
# <td headers="stat_0_1" class="gt_row gt_center">6 (67%)</td>
# <td headers="residuals_1" class="gt_row gt_center">▲</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">33 (61%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▲</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    "araticum"</td>
# <td headers="stat_0_1" class="gt_row gt_center">1 (11%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    pear</td>
# <td headers="stat_0_1" class="gt_row gt_center">1 (11%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    poivre rose</td>
# <td headers="stat_0_1" class="gt_row gt_center">1 (11%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    "café-do-mato" or "café-bugre" and others</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    apple</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    avocado</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    barkley fruit?</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    black mulberry or blackberry</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    chinaberry</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    fig</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">2 (3.7%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    forest olive</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    guava</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    japanese grape</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    lemon</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    loquat</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    mango</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    medlar</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    orange</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    peach</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    plum</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    wild blackberry or thornless blackberry</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">1 (1.9%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Marketable fruits</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.317</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center">0.006</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    no</td>
# <td headers="stat_0_1" class="gt_row gt_center">6 (67%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">37 (69%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    yes</td>
# <td headers="stat_0_1" class="gt_row gt_center">3 (33%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">17 (31%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Power generation (coal or firewood)</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.739</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center">0.680</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    no</td>
# <td headers="stat_0_1" class="gt_row gt_center">4 (44%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">25 (47%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    yes</td>
# <td headers="stat_0_1" class="gt_row gt_center">5 (56%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">28 (53%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Commercial wood</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.096</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center">0.405</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    no</td>
# <td headers="stat_0_1" class="gt_row gt_center">2 (22%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">23 (44%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    yes</td>
# <td headers="stat_0_1" class="gt_row gt_center">7 (78%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">29 (56%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Paper</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.096</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center"><0.001</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    no</td>
# <td headers="stat_0_1" class="gt_row gt_center">7 (78%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">40 (78%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▲</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    yes</td>
# <td headers="stat_0_1" class="gt_row gt_center">2 (22%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">11 (22%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▼</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Urban afforestation</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.317</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center"><0.001</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    no</td>
# <td headers="stat_0_1" class="gt_row gt_center">3 (33%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">13 (25%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▼</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    yes</td>
# <td headers="stat_0_1" class="gt_row gt_center">6 (67%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">40 (75%)</td>
# <td headers="residuals_2" class="gt_row gt_center">▲</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left" style="font-weight: bold;">Agroforestry</td>
# <td headers="stat_0_1" class="gt_row gt_center"><br /></td>
# <td headers="residuals_1" class="gt_row gt_center"><br /></td>
# <td headers="p_1" class="gt_row gt_center">0.317</td>
# <td headers="stat_0_2" class="gt_row gt_center"><br /></td>
# <td headers="residuals_2" class="gt_row gt_center"><br /></td>
# <td headers="p_2" class="gt_row gt_center">0.586</td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    no</td>
# <td headers="stat_0_1" class="gt_row gt_center">3 (33%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">29 (54%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#     <tr><td headers="label" class="gt_row gt_left">    yes</td>
# <td headers="stat_0_1" class="gt_row gt_center">6 (67%)</td>
# <td headers="residuals_1" class="gt_row gt_center">-</td>
# <td headers="p_1" class="gt_row gt_center"><br /></td>
# <td headers="stat_0_2" class="gt_row gt_center">25 (46%)</td>
# <td headers="residuals_2" class="gt_row gt_center">-</td>
# <td headers="p_2" class="gt_row gt_center"><br /></td></tr>
#   </tbody>
#
#   <tfoot class="gt_footnotes">
#     <tr>
#       <td class="gt_footnote" colspan="7"><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>1</sup></span> n (%)</td>
#     </tr>
#     <tr>
#       <td class="gt_footnote" colspan="7"><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>2</sup></span> Frequency classification</td>
#     </tr>
#     <tr>
#       <td class="gt_footnote" colspan="7"><span class="gt_footnote_marks" style="white-space:nowrap;font-style:italic;font-weight:normal;"><sup>3</sup></span> Chi-Square Goodness of Fit Test (α = 0.05)</td>
#     </tr>
#   </tfoot>
# </table>
# </div>
